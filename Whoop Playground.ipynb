# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib

# %%
df = pd.read_csv("whoop-goldencheetah.csv")

# %%
df
# Out:
#    timestamp_measurement  HR  AVNN  SDNN     rMSSD  pNN50  LF  HF  \
# 0    2021-01-19 06:59:48  46   NaN   NaN   98.3970    NaN NaN NaN
# 1    2021-01-20 06:29:40  45   NaN   NaN   87.1359    NaN NaN NaN
# 2    2021-01-21 08:32:16  46   NaN   NaN   97.0674    NaN NaN NaN
# 3    2021-01-22 07:40:28  50   NaN   NaN   88.2508    NaN NaN NaN
# 4    2021-01-23 08:13:00  56   NaN   NaN   90.2764    NaN NaN NaN
# 5    2021-01-24 08:31:10  47   NaN   NaN   88.0271    NaN NaN NaN
# 6    2021-01-25 07:38:11  54   NaN   NaN   72.0429    NaN NaN NaN
# 7    2021-01-26 06:50:38  50   NaN   NaN   86.7140    NaN NaN NaN
# 8    2021-01-27 07:47:58  52   NaN   NaN   67.6414    NaN NaN NaN
# 9    2021-01-28 06:59:06  51   NaN   NaN   90.0317    NaN NaN NaN
# 10   2021-01-29 07:36:40  47   NaN   NaN   88.8795    NaN NaN NaN
# 11   2021-01-30 07:12:13  49   NaN   NaN  116.9830    NaN NaN NaN
# 12   2021-01-31 08:19:11  49   NaN   NaN   82.0803    NaN NaN NaN
# ...

# %%
sns.lineplot(data=df, x="timestamp_measurement", y="HR")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-a30c16446c96> in <module>()
# ----> 1 df["Day"]=df["timestamp_measurement"].split(" ")
#
# /Users/carallen/.pyenv/versions/3.6.9/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'split'
